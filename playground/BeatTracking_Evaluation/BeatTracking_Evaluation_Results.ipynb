# %% [markdown]
# # Beat Tracking Evaluation Results
# This notebook visualizes the beat tracking evaluation results saved from BeatTracking_Evaluation_Test.ipynb.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the evaluation results
try:
    with open('evaluation_results.json', 'r') as f:
        results = json.load(f)
    df = pd.DataFrame(results).T
    display(df)
except FileNotFoundError:
    print('evaluation_results.json not found. Run the Test notebook first.')
